# %% [markdown]
# # Ex 1

# %%
import numpy as np


def get_rot_matrix(alpha):
    al = np.deg2rad(alpha)
    rot = np.array([[np.cos(al), -np.sin(al)], 
                    [np.sin(al), np.cos(al)]])
    return rot

# %%
get_rot_matrix(alpha=-45)
# Out:
# array([[ 0.70710678,  0.70710678],
#        [-0.70710678,  0.70710678]])

# %%
get_rot_matrix(alpha=30)
# Out:
# array([[ 0.8660254, -0.5      ],
#        [ 0.5      ,  0.8660254]])

# %% [markdown]
# ## check

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon


def plot_polygons(p_inp, p_out, x_lim, y_lim):
    fig,(ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
    ax1.add_patch(p_inp)
    ax1.set_xlim(x_lim)
    ax1.set_ylim(y_lim)
    ax2.add_patch(p_out)
    ax2.set_xlim(x_lim)
    ax2.set_ylim(y_lim)
    ax1.grid()
    ax2.grid()
    plt.show()

# %%
obj_input = np.array([[1, 0], [1, 2], [3, 2], [3, 0]])

rot_30 = get_rot_matrix(alpha=45)
obj_out = rot_30.dot(obj_input.T).T

# %%
p_inp = Polygon(obj_input, facecolor = 'orange')
p_out = Polygon(obj_out, facecolor = 'red')

plot_polygons(p_inp, p_out, (-3, 6), (0, 6))

# %% [markdown]
#  # Ex 2

# %%
def rot_around_vec(data, alpha, vec):
    rot_m = get_rot_matrix(alpha)
    rotated = rot_m.dot((data - vec).T).T + vec
    return rotated

# %% [markdown]
# ## a

# %%
c = np.array([2, 3])
alpha = -90

# %%
obj_input = np.array([[2, 3], [1, 2], [4, 2]])
obj_out = rot_around_vec(obj_input, alpha, c)


p_inp = Polygon(obj_input, facecolor = 'orange')
p_out = Polygon(obj_out, facecolor = 'red')
plot_polygons(p_inp, p_out, (0, 6), (0, 6))

# %% [markdown]
# ## b

# %%
c = np.array([-1, 4])
alpha = -45

# %%
obj_input = np.array([[2, 3], [1, 2], [4, 2]])
obj_out = rot_around_vec(obj_input, alpha, c)


p_inp = Polygon(obj_input, facecolor = 'orange')
p_out = Polygon(obj_out, facecolor = 'red')
plot_polygons(p_inp, p_out, (-2, 6), (-2, 6))

# %% [markdown]
# # Ex 3

# %%
x0 = 4
reflect = np.array([[-1, 0, 4], [0, 1, 0], [0, 0, 1]])
obj_input = np.array([[1, 0, 1],
       [1, 2, 1],
       [3, 2, 1]])
obj_out = reflect.dot(obj_input.T).T
obj_out
# Out:
# array([[3, 0, 1],
#        [3, 2, 1],
#        [1, 2, 1]])

# %%
p_inp = Polygon(obj_input[:, :-1], facecolor = 'orange')
p_out = Polygon(obj_out[:, :-1], facecolor = 'red')


plot_polygons(p_inp, p_out, (-3, 6), (0, 6))
